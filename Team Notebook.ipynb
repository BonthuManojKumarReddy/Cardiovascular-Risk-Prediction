# %% [markdown]
# # <b><u> Project Title : Seoul Bike Sharing Demand Prediction </u></b>

# %% [markdown]
# ## <b> Problem Description </b>
#
# ### Currently Rental bikes are introduced in many urban cities for the enhancement of mobility comfort. It is important to make the rental bike available and accessible to the public at the right time as it lessens the waiting time. Eventually, providing the city with a stable supply of rental bikes becomes a major concern. The crucial part is the prediction of bike count required at each hour for the stable supply of rental bikes.

# %% [markdown]
# ## <b> Data Description </b>
#
# ### <b> The dataset contains weather information (Temperature, Humidity, Windspeed, Visibility, Dewpoint, Solar radiation, Snowfall, Rainfall), the number of bikes rented per hour and date information.</b>
#
#
# ### <b>Attribute Information: </b>
#
# * ### Date : year-month-day
# * ### Rented Bike count - Count of bikes rented at each hour
# * ### Hour - Hour of he day
# * ### Temperature-Temperature in Celsius
# * ### Humidity - %
# * ### Windspeed - m/s
# * ### Visibility - 10m
# * ### Dew point temperature - Celsius
# * ### Solar radiation - MJ/m2
# * ### Rainfall - mm
# * ### Snowfall - cm
# * ### Seasons - Winter, Spring, Summer, Autumn
# * ### Holiday - Holiday/No holiday
# * ### Functional Day - NoFunc(Non Functional Hours), Fun(Functional hours)

# %% [markdown]
# # **Import libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Import the dataset**

# %%
# df = pd.read_csv('/content/drive/MyDrive/Almabetter DataScience/Captson2/Bikes count/data/Copy of SeoulBikeData.csv',encoding="ISO-8859-1")

# %%
df=pd.read_csv('https://raw.githubusercontent.com/BonthuManojKumarReddy/ML-1/main/SeoulBikeData.csv',encoding="ISO-8859-1")

# %% [markdown]
# # **Data Inspection**

# %%
df.shape
# Out:
# (8760, 14)

# %%
df.head()
# Out:
#          Date  Rented Bike Count  Hour  ...  Seasons     Holiday  Functioning Day
# 0  01/12/2017                254     0  ...   Winter  No Holiday              Yes
# 1  01/12/2017                204     1  ...   Winter  No Holiday              Yes
# 2  01/12/2017                173     2  ...   Winter  No Holiday              Yes
# 3  01/12/2017                107     3  ...   Winter  No Holiday              Yes
# 4  01/12/2017                 78     4  ...   Winter  No Holiday              Yes
#
# [5 rows x 14 columns]

# %%
df.tail()
# Out:
#             Date  Rented Bike Count  Hour  ...  Seasons     Holiday  Functioning Day
# 8755  30/11/2018               1003    19  ...   Autumn  No Holiday              Yes
# 8756  30/11/2018                764    20  ...   Autumn  No Holiday              Yes
# 8757  30/11/2018                694    21  ...   Autumn  No Holiday              Yes
# 8758  30/11/2018                712    22  ...   Autumn  No Holiday              Yes
# 8759  30/11/2018                584    23  ...   Autumn  No Holiday              Yes
#
# [5 rows x 14 columns]

# %%
# statistical info
df.describe()
# Out:
#        Rented Bike Count         Hour  ...  Rainfall(mm)  Snowfall (cm)
# count        8760.000000  8760.000000  ...   8760.000000    8760.000000
# mean          704.602055    11.500000  ...      0.148687       0.075068
# std           644.997468     6.922582  ...      1.128193       0.436746
# min             0.000000     0.000000  ...      0.000000       0.000000
# 25%           191.000000     5.750000  ...      0.000000       0.000000
# 50%           504.500000    11.500000  ...      0.000000       0.000000
# 75%          1065.250000    17.250000  ...      0.000000       0.000000
# max          3556.000000    23.000000  ...     35.000000       8.800000
#
# [8 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Rented Bike Count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons',
#        'Holiday', 'Functioning Day'],
#       dtype='object')

# %%
#type and shape information/ Summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   object
#  1   Rented Bike Count          8760 non-null   int64
#  2   Hour                       8760 non-null   int64
#  3   Temperature(°C)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(°C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
#  13  Functioning Day            8760 non-null   object
# dtypes: float64(6), int64(4), object(4)
# memory usage: 958.2+ KB

# %%
# duplicate
len(df[df.duplicated()])
# Out:
# 0

# %%
# unique values
df.apply(lambda x: len(x.unique()))
# Out:
# Date                          365
# Rented Bike Count            2166
# Hour                           24
# Temperature(°C)               546
# Humidity(%)                    90
# Wind speed (m/s)               65
# Visibility (10m)             1789
# Dew point temperature(°C)     556
# Solar Radiation (MJ/m2)       345
# Rainfall(mm)                   61
# Snowfall (cm)                  51
# Seasons                         4
# Holiday                         2
# Functioning Day                 2
# dtype: int64

# %% [markdown]
# # **Preprocessing the dataset**

# %%
# checking for null values
df.isnull().sum()
# Out:
# Date                         0
# Rented Bike Count            0
# Hour                         0
# Temperature(°C)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(°C)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functioning Day              0
# dtype: int64

# %% [markdown]
# So add the Month column with the help of the Date

# %%
df['month'] = pd.DatetimeIndex(df['Date']).month

# %% [markdown]
# Rename the Column with specific names

# %%
df = df.rename(columns={'Temperature(°C)':'Temperature',
                       'Humidity(%)':'Humidity',
                       'Snowfall (cm)':'Snowfall',
                       'Solar Radiation (MJ/m2)':'Solar Radiation',
                       'Rainfall(mm)':'Rainfall',
                       'Dew point temperature(°C)':'Dew point temperature',
                        'Visibility (10m)':'Visibility',
                        'Wind speed (m/s)':'Wind speed'})
df.head()
# Out:
#          Date  Rented Bike Count  Hour  ...     Holiday  Functioning Day  month
# 0  01/12/2017                254     0  ...  No Holiday              Yes      1
# 1  01/12/2017                204     1  ...  No Holiday              Yes      1
# 2  01/12/2017                173     2  ...  No Holiday              Yes      1
# 3  01/12/2017                107     3  ...  No Holiday              Yes      1
# 4  01/12/2017                 78     4  ...  No Holiday              Yes      1
#
# [5 rows x 15 columns]

# %%
df.head()
# Out:
#          Date  Rented Bike Count  Hour  ...     Holiday  Functioning Day  month
# 0  01/12/2017                254     0  ...  No Holiday              Yes      1
# 1  01/12/2017                204     1  ...  No Holiday              Yes      1
# 2  01/12/2017                173     2  ...  No Holiday              Yes      1
# 3  01/12/2017                107     3  ...  No Holiday              Yes      1
# 4  01/12/2017                 78     4  ...  No Holiday              Yes      1
#
# [5 rows x 15 columns]

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# **Univariate Analysis**

# %% [markdown]
# Plotting variables to the target

# %%
# Function for plotting each categorical feature against rented_bike_count 
def get_count_plot(x):
  x=x
  y='Rented Bike Count'
  plt.figure(figsize=(15,5))
  sns.barplot(x=x,y=y,data=df)
  plt.title(x+' vs {}'.format(y),fontsize=20)
  plt.xlabel(x,fontsize=15)
  plt.ylabel(y,fontsize=15)

# %% [markdown]
# Plot by hours

# %%
# Hour vs rented_bike_count
get_count_plot('Hour')

# %% [markdown]
# Inference:In morning hours(8-9) and in evening hours (5-8),the bikes taken for rental are more

# %% [markdown]
# Plot by Dates

# %%
#visualisation on Bike Rented 
df.plot(x='Date',y='Rented Bike Count',kind='line',figsize = (20,10))
plt.show()

# %% [markdown]
# So let's focus on the seasons where we have the most rents because at the month of may (5) to july(7) bikes have the most rents.

# %% [markdown]
# Plots by season

# %%
# seasons vs rented_bike_count
get_count_plot('Seasons')

# %%
df.groupby('Seasons').sum()['Rented Bike Count'].plot.pie()
plt.show()

# %% [markdown]
# Inference: Bikes taken for rental are more in Summer and less in Winter

# %% [markdown]
# Plots by Months

# %%
# month vs rented_bike_count
get_count_plot('month')

# %%
a=pd.DataFrame(df.groupby('month').sum()['Rented Bike Count'].sort_values(ascending=True))
a=a.sort_values('month',ascending=True)
a.plot(figsize = (15,7))
plt.show()

# %% [markdown]
# Inference: Bike rentals are more from May to August month

# %% [markdown]
# Plots By Day

# %%
# Covert Date also into the day
df['Date']=pd.to_datetime(df['Date'],format="%d/%m/%Y")

df['Day']=df["Date"].dt.day_name()

# %%
get_count_plot('Day')

# %%
pd.DataFrame(df.groupby('Day').sum()['Rented Bike Count'].sort_values(ascending=False)).plot(figsize = (15,7))
plt.show()

# %%
df1VizDays=pd.DataFrame(df.groupby('Day').sum()['Rented Bike Count'].sort_values(ascending=False))
df1VizDays.style.background_gradient(cmap=sns.light_palette("red", as_cmap=True))
# Out:
# <style  type="text/css" >
# #T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row0_col0{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row1_col0{
#             background-color:  #fd2525;
#             color:  #f1f1f1;
#         }#T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row2_col0{
#             background-color:  #fc3737;
#             color:  #f1f1f1;
#         }#T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row3_col0{
#             background-color:  #fa5b5b;
#             color:  #000000;
#         }#T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row4_col0{
#             background-color:  #f97c7c;
#             color:  #000000;
#         }#T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row5_col0{
#             background-color:  #f88282;
#             color:  #000000;
#         }#T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row6_col0{
#             background-color:  #f3f0f0;
#             color:  #000000;
#         }</style><table id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Rented Bike Count</th>    </tr>    <tr>        <th class="index_name level0" >Day</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002level0_row0" class="row_heading level0 row0" >Friday</th>
#                         <td id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row0_col0" class="data row0 col0" >950334</td>
#             </tr>
#             <tr>
#                         <th id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002level0_row1" class="row_heading level0 row1" >Wednesday</th>
#                         <td id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row1_col0" class="data row1 col0" >923956</td>
#             </tr>
#             <tr>
#                         <th id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002level0_row2" class="row_heading level0 row2" >Monday</th>
#                         <td id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row2_col0" class="data row2 col0" >911743</td>
#             </tr>
#             <tr>
#                         <th id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002level0_row3" class="row_heading level0 row3" >Saturday</th>
#                         <td id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row3_col0" class="data row3 col0" >885492</td>
#             </tr>
#             <tr>
#                         <th id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002level0_row4" class="row_heading level0 row4" >Thursday</th>
#                         <td id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row4_col0" class="data row4 col0" >861999</td>
#             </tr>
#             <tr>
#                         <th id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002level0_row5" class="row_heading level0 row5" >Tuesday</th>
#                         <td id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row5_col0" class="data row5 col0" >858596</td>
#             </tr>
#             <tr>
#                         <th id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002level0_row6" class="row_heading level0 row6" >Sunday</th>
#                         <td id="T_fbc5bb0c_b227_11eb_846f_0242ac1c0002row6_col0" class="data row6 col0" >780194</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Here we see at the weekend Bike goes to be rented less compare to the working days

# %% [markdown]
# Plots by Holiday

# %%
# holiday vs rented_bike_count
get_count_plot('Holiday')

# %%
df.groupby('Holiday').sum()['Rented Bike Count'].plot.pie(radius=1.5)

# %% [markdown]
# Inference: During No Holidays,the bikes taken for rental are more than during holidays

# %% [markdown]
# Plots by Functioning Day and Non functioning day

# %%
# functioning_day vs rented_bike_count
sns.barplot(x='Functioning Day',y='Rented Bike Count',data=df)

# %% [markdown]
# Inference: Bikes for rental are very high during functioning days

# %% [markdown]
# Plots by Rainfall

# %%
df.groupby('Rainfall').mean()['Rented Bike Count'].plot()

# %% [markdown]
# We can see that even if it rains a lot of rent bikes, here for example even if we have 20 mm of rain there is a big peak of rented bikes

# %% [markdown]
# Plots By Snowfall

# %%
df.groupby('Snowfall').mean()['Rented Bike Count'].plot()

# %% [markdown]
# Inference:When we have more than 4 cm of snow, the bike rents is much lower

# %% [markdown]
# Plots By Temperature

# %%
df.groupby('Temperature').mean()['Rented Bike Count'].plot()

# %% [markdown]
# Inference:people like to ride bikes when it is pretty hot around 25°C in average

# %% [markdown]
# Variable which informs us if it is night or day

# %%
df['label_day_night']=df['Hour'].apply(lambda x : 'Night' if (x >20 or x<5) else( 'Day'))

# %% [markdown]
# Let's see the repartition of the rents follonwing the moment of the day

# %%
df.groupby('label_day_night').sum()['Rented Bike Count'].plot.pie()

# %% [markdown]
# Inference:Number of Bike Rented in day is high as compare to the night

# %% [markdown]
# **Bivariate Analysis**

# %%
# Function for plotting one feature against another
def get_plot(x,hue):
  x=x
  hue=hue
  y='Rented Bike Count'
  plt.figure(figsize=(17,5))
  sns.pointplot(x=x,y=y,hue=hue,data=df)
  plt.xlabel(x,fontsize=(15))
  plt.ylabel(y,fontsize=(15))
  plt.title(y+' '+'during different {}'.format(hue),fontsize=(20))

# %%
# Hourly rental bike counts during different seasons
get_plot('Hour','Seasons')

# %% [markdown]
# Inference:
#
# 1)During Summer ,rented bikes are more in each hour than other seasons
#
# 2)During Winter ,rented bikes are less in each hour compared to other seasons

# %%
# Hourly rental bike counts during different holiday
get_plot('Hour','Holiday')

# %% [markdown]
# Inference: During No Holiday,rented bikes are more than during Holidays in each hour

# %%
# Hourly rental bike counts during different functioning days
get_plot('Hour','Functioning Day')

# %% [markdown]
# Inference: During functioning days,rented bikes count is more than non_functioning days in each hour

# %%
# Hourly rental bike counts during different months
get_plot('Hour','month')

# %% [markdown]
# Inference:During may,june,july and august months rented bikes count is observed more during 5pm to 7pm

# %%
# Seasonly rental bikes count during different hours
get_plot('Seasons','Hour')

# %% [markdown]
# Inference:
#
# 1)In all seasons,during 5pm-6pm rented bike counts are more
#
# 2)During Summer,5pm-9pm rented bike counts are more

# %%
# Seasonly rental bikes count during different hours
get_plot('Hour','Day')

# %% [markdown]
# Inference:
#
#  At Saturday and Sunday we see the Bike rented is less but at the evening time it goes bit up.
#
#  Monday to friday all the hours seems like same for the Rented Bike count

# %% [markdown]
# **Some preprocess with data**

# %% [markdown]
# Convert Values to FLoat

# %%
colms = ['Humidity','Visibility']

for col in colms:
    df[col] = df[col].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   8760 non-null   datetime64[ns]
#  1   Rented Bike Count      8760 non-null   int64
#  2   Hour                   8760 non-null   int64
#  3   Temperature            8760 non-null   float64
#  4   Humidity               8760 non-null   float64
#  5   Wind speed             8760 non-null   float64
#  6   Visibility             8760 non-null   float64
#  7   Dew point temperature  8760 non-null   float64
#  8   Solar Radiation        8760 non-null   float64
#  9   Rainfall               8760 non-null   float64
#  10  Snowfall               8760 non-null   float64
#  11  Seasons                8760 non-null   object
#  12  Holiday                8760 non-null   object
#  13  Functioning Day        8760 non-null   object
#  14  month                  8760 non-null   int64
#  15  Day                    8760 non-null   object
#  16  label_day_night        8760 non-null   object
# dtypes: datetime64[ns](1), float64(8), int64(3), object(5)
# memory usage: 1.1+ MB

# %%
# Changing datatype object to category
cols = ['Seasons','month','Hour','Holiday','Functioning Day']

for col in cols:
    df[col] = df[col].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   8760 non-null   datetime64[ns]
#  1   Rented Bike Count      8760 non-null   int64
#  2   Hour                   8760 non-null   category
#  3   Temperature            8760 non-null   float64
#  4   Humidity               8760 non-null   float64
#  5   Wind speed             8760 non-null   float64
#  6   Visibility             8760 non-null   float64
#  7   Dew point temperature  8760 non-null   float64
#  8   Solar Radiation        8760 non-null   float64
#  9   Rainfall               8760 non-null   float64
#  10  Snowfall               8760 non-null   float64
#  11  Seasons                8760 non-null   category
#  12  Holiday                8760 non-null   category
#  13  Functioning Day        8760 non-null   category
#  14  month                  8760 non-null   category
#  15  Day                    8760 non-null   object
#  16  label_day_night        8760 non-null   object
# dtypes: category(5), datetime64[ns](1), float64(8), int64(1), object(2)
# memory usage: 865.7+ KB

# %% [markdown]
# Convert Categorical columns to Encoded number

# %%
encoders_nums = {"Holiday":{"Holiday":1,"No Holiday":0},
                 "Functioning Day":{"Yes":1,"No":0}}

df = df.replace(encoders_nums)

# %% [markdown]
# Some Basic Analysis

# %%
# Dependent variable 'Rented Bike Count'
plt.figure(figsize=(7,7))
sns.distplot(df['Rented Bike Count'],color="y")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Right Skewed so Need to normalize the this Column

# %%
df['Rented Bike Count'] = np.log(df['Rented Bike Count'])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Dependent variable 'Rented Bike Count'
plt.figure(figsize=(7,7))
sns.distplot(np.log10(df['Rented Bike Count']),color="y")
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Let's See some of the Plots for Neumerical data

# %%
numeric_features = df.describe().columns
numeric_features
# Out:
# Index(['Rented Bike Count', 'Temperature', 'Humidity', 'Wind speed',
#        'Visibility', 'Dew point temperature', 'Solar Radiation', 'Rainfall',
#        'Snowfall', 'Holiday', 'Functioning Day'],
#       dtype='object')

# %%
# plot a bar plot for each numerical feature count (except car_ID)

for col in numeric_features[1:]:
    fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    feature = df[col]
    feature.hist(bins=50, ax = ax)
    ax.axvline(feature.mean(), color='magenta', linestyle='dashed', linewidth=2)
    ax.axvline(feature.median(), color='cyan', linestyle='dashed', linewidth=2)    
    ax.set_title(col)
plt.show()

# %% [markdown]
# Scatter Plots drawn with Numerical data

# %%
for col in numeric_features[1:]:
    fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    feature = df[col]
    label = df['Rented Bike Count']
    correlation = feature.corr(label)
    plt.scatter(x=feature, y=label)
    plt.xlabel(col)
    plt.ylabel('Rented Bike Count')
    ax.set_title('Rented Bike Count vs ' + col + '- correlation: ' + str(correlation))
    z = np.polyfit(df[col], df['Rented Bike Count'], 1)
    y_hat = np.poly1d(z)(df[col])

    plt.plot(df[col], y_hat, "r--", lw=1)

plt.show()

# %% [markdown]
# To fine the correlation between the data set neet to make the heatmap

# %%
 ## Correlation
plt.figure(figsize=(15,8))
correlation = df.corr()
sns.heatmap(abs(correlation), annot=True, cmap='coolwarm')

# %% [markdown]
# We see that Correlation between the Temperature and Dew Point Temperature is very high so we remove the Dew point temperature because the correlation with the Rented Bike Count with Temperature is more.

# %%
df.drop('Dew point temperature',axis='columns', inplace=True)

# %%
 ## Correlation
plt.figure(figsize=(15,8))
correlation = df.corr()
sns.heatmap(abs(correlation), annot=True, cmap='coolwarm')

# %% [markdown]
# Lets plot for Categorical data

# %%
categorical_features = df.describe(include=['object','category']).columns

# %%
for col in categorical_features:
    counts = df[col].value_counts().sort_index()
    fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    counts.plot.bar(ax = ax, color='steelblue')
    ax.set_title(col + ' counts')
    ax.set_xlabel(col) 
    ax.set_ylabel("Frequency")
plt.show()

# %% [markdown]
# Box plot for Categorical Data

# %%
for col in categorical_features:
    fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    df.boxplot(column = 'Rented Bike Count', by = col, ax = ax)
    ax.set_title('Label by ' + col)
    ax.set_ylabel("Bike COunt")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# **Need to drop some of the Columns for the Prediction**

# %% [markdown]
# Drop the Date Column

# %%
df = df.drop(columns='Date')

# %%
len(df[df['Rainfall']==0.0])
# Out:
# 8232

# %%
len(df[df['Snowfall']==0.0])
# Out:
# 8317

# %%
df.drop('Rainfall',axis='columns', inplace=True)

# %%
df.drop('Snowfall',axis='columns', inplace=True)

# %% [markdown]
# We create the variable to encode WeekDay

# %%
mapping_dictDay={'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5,'Saturday':6,'Sunday':7}

df['WeekDayEncoding']=df['Day'].map(mapping_dictDay)

# %%
df.drop('Day',axis='columns', inplace=True)

# %%
df.drop('label_day_night',axis='columns', inplace=True)

# %% [markdown]
# **Need to perform Hot Encoding with the categorical data**

# %%
# One hot encoding
df = pd.get_dummies(df, columns=["Hour", "Seasons","month","WeekDayEncoding"], prefix=["hour", "season","month","weekDay"],drop_first=True)

# %%
df.head()
# Out:
#    Rented Bike Count  Temperature  Humidity  ...  weekDay_5  weekDay_6  weekDay_7
# 0           5.537334         -5.2      37.0  ...          1          0          0
# 1           5.318120         -5.5      38.0  ...          1          0          0
# 2           5.153292         -6.0      39.0  ...          1          0          0
# 3           4.672829         -6.2      40.0  ...          1          0          0
# 4           4.356709         -6.0      36.0  ...          1          0          0
#
# [5 rows x 51 columns]

# %%
df.columns
# Out:
# Index(['Rented Bike Count', 'Temperature', 'Humidity', 'Wind speed',
#        'Visibility', 'Solar Radiation', 'Holiday', 'Functioning Day', 'hour_1',
#        'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6', 'hour_7', 'hour_8',
#        'hour_9', 'hour_10', 'hour_11', 'hour_12', 'hour_13', 'hour_14',
#        'hour_15', 'hour_16', 'hour_17', 'hour_18', 'hour_19', 'hour_20',
#        'hour_21', 'hour_22', 'hour_23', 'season_Spring', 'season_Summer',
#        'season_Winter', 'month_2', 'month_3', 'month_4', 'month_5', 'month_6',
#        'month_7', 'month_8', 'month_9', 'month_10', 'month_11', 'month_12',
#        'weekDay_2', 'weekDay_3', 'weekDay_4', 'weekDay_5', 'weekDay_6',
#        'weekDay_7'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 51 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rented Bike Count  8462 non-null   float64
#  1   Temperature        8760 non-null   float64
#  2   Humidity           8760 non-null   float64
#  3   Wind speed         8760 non-null   float64
#  4   Visibility         8760 non-null   float64
#  5   Solar Radiation    8760 non-null   float64
#  6   Holiday            8760 non-null   int64
#  7   Functioning Day    8760 non-null   int64
#  8   hour_1             8760 non-null   uint8
#  9   hour_2             8760 non-null   uint8
#  10  hour_3             8760 non-null   uint8
#  11  hour_4             8760 non-null   uint8
#  12  hour_5             8760 non-null   uint8
#  13  hour_6             8760 non-null   uint8
#  14  hour_7             8760 non-null   uint8
#  15  hour_8             8760 non-null   uint8
#  16  hour_9             8760 non-null   uint8
#  17  hour_10            8760 non-null   uint8
#  18  hour_11            8760 non-null   uint8
#  19  hour_12            8760 non-null   uint8
#  20  hour_13            8760 non-null   uint8
#  21  hour_14            8760 non-null   uint8
#  22  hour_15            8760 non-null   uint8
#  23  hour_16            8760 non-null   uint8
#  24  hour_17            8760 non-null   uint8
#  25  hour_18            8760 non-null   uint8
#  26  hour_19            8760 non-null   uint8
#  27  hour_20            8760 non-null   uint8
#  28  hour_21            8760 non-null   uint8
#  29  hour_22            8760 non-null   uint8
#  30  hour_23            8760 non-null   uint8
#  31  season_Spring      8760 non-null   uint8
#  32  season_Summer      8760 non-null   uint8
#  33  season_Winter      8760 non-null   uint8
#  34  month_2            8760 non-null   uint8
#  35  month_3            8760 non-null   uint8
#  36  month_4            8760 non-null   uint8
#  37  month_5            8760 non-null   uint8
#  38  month_6            8760 non-null   uint8
#  39  month_7            8760 non-null   uint8
#  40  month_8            8760 non-null   uint8
#  41  month_9            8760 non-null   uint8
#  42  month_10           8760 non-null   uint8
#  43  month_11           8760 non-null   uint8
#  44  month_12           8760 non-null   uint8
#  45  weekDay_2          8760 non-null   uint8
#  46  weekDay_3          8760 non-null   uint8
#  47  weekDay_4          8760 non-null   uint8
#  48  weekDay_5          8760 non-null   uint8
#  49  weekDay_6          8760 non-null   uint8
#  50  weekDay_7          8760 non-null   uint8
# dtypes: float64(6), int64(2), uint8(43)
# memory usage: 915.5 KB

# %%
df.shape
# Out:
# (8760, 51)

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
df=clean_dataset(df)

# %%
df.shape
# Out:
# (8465, 51)

# %% [markdown]
# ## **Split the Data Set**

# %%
Y = df['Rented Bike Count']
X = df.drop(columns='Rented Bike Count', axis=1)

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split( X,Y, test_size = 0.2, random_state = 0) 
print(X_train.shape)
print(X_test.shape)
# Out:
# (6772, 50)
# (1693, 50)

# %% [markdown]
# # **Modeling**

# %% [markdown]
# First Try with **Linear Regression** to make the prediction

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression().fit(X_train, y_train)

# %%
# Predicting the Test set results
y_pred = reg.predict(X_test)

# %% [markdown]
# Calculate the value of the **MSE** and **RMSE**

# %%
from sklearn.metrics import mean_squared_error

MSE  = mean_squared_error((y_test),(y_pred))
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# MSE : 0.5064503030007469
# RMSE : 0.7116532182184993

# %% [markdown]
# Calculate the value of the **R2**

# %%
from sklearn.metrics import r2_score
r2 = r2_score((y_test),(y_pred))
print("R2 :" ,r2)
print("Adjusted R2 : ",1-(1-r2_score((y_test),(y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# R2 : 0.6349747136136711
# Adjusted R2 :  0.6238594491073882

# %% [markdown]
# Here we find the value of R2 is quite not good so we go with other algorithm.

# %% [markdown]
# **Try To find the Algorithm which is more suitable for the DataSet**

# %%
from sklearn.linear_model import LinearRegression, Ridge, HuberRegressor, ElasticNetCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor

models = [LinearRegression(),
         Ridge(),
         HuberRegressor(),
         ElasticNetCV(),
         DecisionTreeRegressor(),
         RandomForestRegressor(),
         ExtraTreesRegressor(),
         GradientBoostingRegressor()]

# %%
from sklearn import model_selection
def train(model):
    kfold = model_selection.KFold(n_splits=5, random_state=42)
    pred = model_selection.cross_val_score(model, X, Y, cv=kfold, scoring='neg_mean_squared_error')
    cv_score = pred.mean()
    print('Model:',model)
    print('CV score:', abs(cv_score))

# %%
for model in models:
    train(model)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Model: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# CV score: 0.5596286335412897
# Model: Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)
# CV score: 0.5589188016538762
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Model: HuberRegressor(alpha=0.0001, epsilon=1.35, fit_intercept=True, max_iter=100,
#                tol=1e-05, warm_start=False)
# CV score: 1.3389634405752444
# Model: ElasticNetCV(alphas=None, copy_X=True, cv=None, eps=0.001, fit_intercept=True,
#              l1_ratio=0.5, max_iter=1000, n_alphas=100, n_jobs=None,
#              normalize=False, positive=False, precompute='auto',
#              random_state=None, selection='cyclic', tol=0.0001, verbose=0)
# CV score: 0.8465942024148123
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Model: DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')
# CV score: 0.7624360575778588
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Model: RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
# CV score: 0.45941271216050195
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Model: ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)
# CV score: 0.3776215105518411
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# Model: GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)
# CV score: 0.38829494261341085

# %% [markdown]
# For the Previous CV Score we see that **Random Forest, Extra Regression and   Gradient Boosting** work fine for the Dataset

# %% [markdown]
# # **Let's Apply Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor
rf_exp = RandomForestRegressor(n_estimators= 1000, random_state=100)
rf_exp.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=1000, n_jobs=None, oob_score=False,
#                       random_state=100, verbose=0, warm_start=False)

# %%
predictions = rf_exp.predict(X_test)
# Performance metrics
errors = abs(predictions - y_test)

# %%
print('Metrics for Random Forest Trained on Expanded Data')
print('Average absolute error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Metrics for Random Forest Trained on Expanded Data
# Average absolute error: 0.27 degrees.

# %%
mape = np.mean(100 * (errors / y_test))

# %%
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 94.0 %.

# %%
MSE  = mean_squared_error((y_test),(predictions))
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

r2 = r2_score((y_test),(predictions))
print("R2 :" ,r2)
print("Adjusted R2 : ",1-(1-r2_score((y_test),(predictions)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# MSE : 0.22713231786046767
# RMSE : 0.47658400923705746
# R2 : 0.8362938300493313
# Adjusted R2 :  0.8313088675051574

# %%
features = X_train.columns
importances = rf_exp.feature_importances_
indices = np.argsort(importances)

# %% [markdown]
# Plot the Graph of the Features Importance

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8,9)
plt.title('Feature Importance')
plt.barh(range(len(indices)), importances[indices], color='red', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')

plt.show()

# %%
plt.figure(figsize=(18,5))
plt.plot(10**(predictions))
plt.plot(np.array(10**(y_test)))
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# Inferences:
#
# The Random Forest Model gives the better R2 Score.
#
# The Value of MSE and RMSE is also less.
#
# The model give the Accuracy of 94.0%

# %% [markdown]
# **Random Forest with Different Parameter**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

from pylab import rcParams
rcParams['figure.figsize'] = 8, 8

# %%
randomForestAlgo = RandomForestRegressor()


param = {'n_estimators' : [int(x) for x in np.linspace(start=10,stop=100, num=10)], 
         'max_depth' : [60,70,80,90,100],
         'min_samples_split':[2,4,6,8],
         'min_samples_leaf':[1,2,3,4],
         'bootstrap' : [True,False]
        }

gridSearch_RandomForest=GridSearchCV(randomForestAlgo,param,scoring='r2',cv=5,verbose=2,n_jobs=-1)
best_mode_try=gridSearch_RandomForest.fit(X_train,y_train)

# %%
best_mode_try.best_params_

# %% [markdown]
# Output:
#
# {'bootstrap': True,
#   'max_depth': 70,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 90}

# %%
randomForestAlgo = RandomForestRegressor()
param = {'bootstrap': [True],
         'max_depth': [70],
         'min_samples_leaf': [1],
        'min_samples_split': [2],
         'n_estimators': [90]}

gridSearch_RandomForest=GridSearchCV(randomForestAlgo,param,scoring='r2',cv=5,verbose=2,n_jobs=-1)
best_mode_try=gridSearch_RandomForest.fit(X_train,y_train)

# %%
y_random_pred=best_mode_try.predict(X_test)

# %%
MSE  = mean_squared_error((y_test),(y_random_pred))
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

r2 = r2_score((y_test),(y_random_pred))
print("R2 :" ,r2)
print("Adjusted R2 : ",1-(1-r2_score((y_test),(y_random_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))

# %%
errors = abs(y_random_pred - y_test)

# %%
print('Metrics for Random Forest Trained on Expanded Data')
print('Average absolute error:', round(np.mean(errors), 2), 'degrees.')

# %%
mape = np.mean(100 * (errors / y_test))

# %%
mape = np.mean(100 * (errors / y_test))

# %% [markdown]
# Inferences:
#
# The Random Forest Model with paramater also gives the better R2 Score.
#
# The Value of MSE and RMSE is also less.
#
# The model give the Accuracy of 93.93%

# %% [markdown]
# # **Inference**:
#
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)
